# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
mpl.style.use('seaborn')

# Establecer el estilo 'bmh'
# plt.style.use('bmh')

# Establecer el estilo 'classic'
# plt.style.use('classic')

# Establecer el estilo 'dark_background'
# plt.style.use('dark_background')

# Establecer el estilo 'fast'
# plt.style.use('fast')

# Establecer el estilo 'fivethirtyeight'
# plt.style.use('fivethirtyeight')

# Establecer el estilo 'ggplot'
# plt.style.use('ggplot')

# Establecer el estilo 'grayscale'
# plt.style.use('grayscale')

# Establecer el estilo 'seaborn'
# plt.style.use('seaborn')

# Establecer el estilo 'seaborn-bright'
# plt.style.use('seaborn-bright')

# Establecer el estilo 'seaborn-colorblind'
# plt.style.use('seaborn-colorblind')

# Establecer el estilo 'seaborn-dark'
# plt.style.use('seaborn-dark')

# Establecer el estilo 'seaborn-dark-palette'
# plt.style.use('seaborn-dark-palette')

# Establecer el estilo 'seaborn-darkgrid'
# plt.style.use('seaborn-darkgrid')

# Establecer el estilo 'seaborn-deep'
# plt.style.use('seaborn-deep')

# Establecer el estilo 'seaborn-muted'
# plt.style.use('seaborn-muted')

# Establecer el estilo 'seaborn-notebook'
# plt.style.use('seaborn-notebook')

# Establecer el estilo 'seaborn-paper'
# plt.style.use('seaborn-paper')

# Establecer el estilo 'seaborn-pastel'
# plt.style.use('seaborn-pastel')

# Establecer el estilo 'seaborn-poster'
# plt.style.use('seaborn-poster')

# Establecer el estilo 'seaborn-talk'
# plt.style.use('seaborn-talk')

# Establecer el estilo 'seaborn-ticks'
# plt.style.use('seaborn-ticks')

# Establecer el estilo 'seaborn-white'
# plt.style.use('seaborn-white')

# Establecer el estilo 'seaborn-whitegrid'
# plt.style.use('seaborn-whitegrid')

# Establecer el estilo 'tableau-colorblind10'
# plt.style.use('tableau-colorblind10')
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_4856\281332018.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   mpl.style.use('seaborn')

# %%
mpl.style.use('seaborn') # estilo de grafico ( entre varios) o ggplot
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_4856\619357941.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   mpl.style.use('seaborn') # estilo de grafico ( entre varios) o ggplot

# %%
# fig = figura, ax = ejes (interfaz orientada a objetos)
fig, ax = plt.subplots() 
# los ejes van a tomar esos valores que les paso en una tupla, y dentro de ella dos listas
ax.plot([0, 3], [2, 10])  # primero el eje x

# %%
plt.plot([1, 3], [2, 4]) # le paso otros valores ORIENTADO A ESTADOS

# %%
# documentacion matploblib.org

# Crear una figura y ejes
fig, ax = plt.subplots()

# Trazar una línea en el gráfico
ax.plot([1,3], [2, 4], color='k')

# Establecer los límites de los ejes ( acoto )
# 
ax.set_ylim([2, 4])
ax.set_xlim([1, 3])

# Establecer etiquetas de los ejes
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')

# Establecer el título del gráfico
ax.set_title('Gráfico X vs Y ')

# Agregar una línea horizontal (pornele lineas ( ej medias para tener referencias))
# le paso las customizaciones
ax.axhline(y=3, xmin=0, xmax=4, color='m')

# Agregar una línea vertical
ax.axvline(x=2.0, ymin=0, ymax=10, color='r')

# Mostrar el gráfico
plt.show()

# %%
# Crear una figura y ejes
fig, ax = plt.subplots()

# Trazar una línea en el gráfico
ax.plot([1, 8], [2, 7], color='k')

# Establecer ticks en el eje y con paso 0.5 (ARANGE PARA FLOTANTES)
ax.set_yticks(np.arange(1.0, 10.0, 0.5))

# Establecer ticks en el eje x  (RANGE PARA ENTEROS)
ax.set_xticks(range(0, 11)) # recordar q usa los indices

# Mostrar el gráfico
plt.show()

# %%
import pandas as pd
df_lluvia=pd.read_csv('./pune_1965_to_2002.csv', sep=",",index_col=0)
df_lluvia.head()
# Out:
#         Jan    Feb    Mar     Apr     May      Jun      Jul      Aug      Sep  \
# Year
# 1965  0.029  0.069  0.000  21.667  17.859  102.111  606.071  402.521   69.511
# 1966  0.905  0.000  0.000   2.981  63.008   94.088  481.942   59.386  150.624
# 1967  0.248  3.390  1.320  13.482  11.116  251.314  780.006  181.069  183.757
# 1968  0.318  3.035  1.704  23.307   7.441  179.872  379.354  171.979  219.884
# 1969  0.248  2.524  0.334   4.569   6.213  393.682  678.354  397.335  205.413
#
#          Oct     Nov     Dec
# Year
# 1965   5.249  16.232  22.075
# 1966   1.308  41.214   4.132
# 1967  50.404   8.393  37.685
# 1968  73.997  23.326   2.020
# 1969  24.014  24.385   1.951

# %%
df_lluvia.sum(axis='columns') # le espefico por donde me sume en este caso columnaas
# Out:
# Year
# 1965    1263.394
# 1966     899.588
# 1967    1522.184
# 1968    1086.237
# 1969    1739.022
# 1970    1273.507
# 1971    1176.612
# 1972     710.475
# 1973    1570.073
# 1974    1425.876
# 1975    1777.838
# 1976    1941.167
# 1977    1202.154
# 1978    1168.583
# 1979    1769.187
# 1980    1268.185
# 1981    1562.761
# 1982     943.087
# 1983    1616.948
# 1984    1538.961
# 1985    1214.852
# 1986    1267.969
# 1987    1197.999
# 1988    1822.649
# 1989    1400.024
# 1990    1766.294
# 1991    1497.256
# 1992    1323.883
# 1993    1210.252
# 1994    1987.689
# 1995    1209.068
# 1996    1631.331
# 1997    1844.840
# 1998    1603.243
# 1999    1235.683
# 2000    1094.062
# 2001    1045.825
# 2002    1024.881
# dtype: float64

# %%
print(df_lluvia.groupby('Year')['Jan','Feb','Mar'].sum().head(15))
#este groupby no tiene sentido, ya el df original esta agrupado por años
# en fin me muestra cuanto llovio en los años y los meses separados
# Out:
#         Jan    Feb    Mar
# Year
# 1965  0.029  0.069  0.000
# 1966  0.905  0.000  0.000
# 1967  0.248  3.390  1.320
# 1968  0.318  3.035  1.704
# 1969  0.248  2.524  0.334
# 1970  0.070  0.000  0.001
# 1971  0.000  0.000  0.000
# 1972  0.000  0.029  0.000
# 1973  0.000  2.969  0.234
# 1974  0.000  0.000  6.427
# 1975  0.333  0.585  0.000
# 1976  0.000  0.000  5.993
# 1977  0.000  2.981  3.289
# 1978  0.061  4.197  4.004
# 1979  0.000  0.386  3.343
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_4856\4133325338.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   print(df_lluvia.groupby('Year')['Jan','Feb','Mar'].sum().head(15))

# %%
resul=df_lluvia.groupby('Year')['Jan'].count().head(15)
print(resul)
# Out:
# Year
# 1965    1
# 1966    1
# 1967    1
# 1968    1
# 1969    1
# 1970    1
# 1971    1
# 1972    1
# 1973    1
# 1974    1
# 1975    1
# 1976    1
# 1977    1
# 1978    1
# 1979    1
# Name: Jan, dtype: int64

# %%
x = df_lluvia.index # en un arreglo saco los indices que son los años
print(x)
# Out:
# Int64Index([1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975,
#             1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#             1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#             1998, 1999, 2000, 2001, 2002],
#            dtype='int64', name='Year')

# %%
y = df_lluvia.sum(axis='columns')
y
# Out:
# Year
# 1965    1263.394
# 1966     899.588
# 1967    1522.184
# 1968    1086.237
# 1969    1739.022
# 1970    1273.507
# 1971    1176.612
# 1972     710.475
# 1973    1570.073
# 1974    1425.876
# 1975    1777.838
# 1976    1941.167
# 1977    1202.154
# 1978    1168.583
# 1979    1769.187
# 1980    1268.185
# 1981    1562.761
# 1982     943.087
# 1983    1616.948
# 1984    1538.961
# 1985    1214.852
# 1986    1267.969
# 1987    1197.999
# 1988    1822.649
# 1989    1400.024
# 1990    1766.294
# 1991    1497.256
# 1992    1323.883
# 1993    1210.252
# 1994    1987.689
# 1995    1209.068
# 1996    1631.331
# 1997    1844.840
# 1998    1603.243
# 1999    1235.683
# 2000    1094.062
# 2001    1045.825
# 2002    1024.881
# dtype: float64

# %%
# Crear una figura y ejes utilizando la función subplots() de Matplotlib
fig, ax = plt.subplots(figsize=(12, 4))

# Dibujar un gráfico de línea con los valores de x e y, y asignarle una etiqueta
ax.plot(x, y, label='Precipitaciones acumuladas')

# Establecer el texto del eje x como "Año"
ax.set_xlabel('Año')

# Establecer el texto del eje y como "Precipitación acumulada (mm.)"
ax.set_ylabel('Precipitación acumulada (mm.)')

# Establecer el título del gráfico como "Precipitaciones acumuladas según el año"
ax.set_title('Precipitaciones acumuladas según el año')

# Mostrar la leyenda del gráfico (Precipitaciones acumuladas)
ax.legend()

# Descomentar la siguiente línea si se desea especificar la ubicación de la leyenda en el gráfico
# ax.legend(loc='lower left')

# %%
# Crear una figura y ejes con tamaño personalizado
fig, ax = plt.subplots(figsize=(12, 4))

# Establecer los límites del eje x basados en los índices del DataFrame (desde posicion 0 hasta el dinal ?)
# para asegurar que muestre todos los valores
ax.set_xlim(df_lluvia.index[0], df_lluvia.index[-1])

# Dibujar el gráfico de línea
ax.plot(x, y, label='Precipitaciones acumuladas')

# Establecer etiquetas de los ejes
ax.set_xlabel('Año')
ax.set_ylabel('Precipitación acumulada (mm.)')

# Establecer el título del gráfico
ax.set_title('Precipitaciones acumuladas según el año')

# Mostrar la leyenda
ax.legend()

plt.show()

# %%
# Crear una figura y ejes con tamaño personalizado
fig, ax = plt.subplots(figsize=(12, 4))

# Establecer los límites del eje x basados en los índices del DataFrame
ax.set_xlim(df_lluvia.index[0], df_lluvia.index[-1])

# Dibujar el gráfico de línea
ax.plot(x, y, label='Precipitaciones acumuladas')

# Establecer etiquetas de los ejes
ax.set_xlabel('Año')
ax.set_ylabel('Precipitación acumulada (mm.)')

# Establecer el título del gráfico
ax.set_title('Precipitaciones acumuladas según el año')

# Mostrar la leyenda
ax.legend()

# Configurar los ticks del eje x
# ax.set_xticks(range(1964, 2003, 2)) ver con profe

# Mostrar el gráfico
plt.show()

# %%
fig.savefig("./precipitaciones_año.pdf") # guardo el ultimo grafico en un archivo pdf

# %%
pesos = [42.8, 43.3, 42. , 44. , 44.1, 43.5, 48.1, 48.9, 47.7,46.9,50.4,
       52.7, 51.8, 54.5, 54.2, 56.9, 55.4, 55.5, 57.1, 58.3, 63.7, 58.8,
       64.6, 60.2, 64. , 63.8, 61.4, 66.3, 64.7, 63.9, 69.3, 67.9, 65.2,
       70.8, 70.5, 69.3, 75.3, 75.5, 78.2, 78. , 73.2, 78. , 80.1, 78.2,
       76. , 81.5, 79.4, 81.8, 81.8, 84.1]
alturas = [149. , 149. , 149.9, 156.8, 150.6, 155.4, 151. , 162. , 165.,
       157.8, 164.4, 160.1, 160.8, 163.8, 175.2, 162. , 159.5, 159.2,
       169.8, 166.7, 179.4, 180.6, 163.3, 178.8, 176.3, 184.8, 181. ,
       170.5, 184.1, 187.1, 187.1, 177.7, 184.5, 190.3, 196. , 192.1,
       200.4, 201.8, 187.5, 202.1, 200.3, 208.8, 204.6, 193.5, 200.9,
       196.8, 213.1, 204.8, 215.5, 210.2]

# %%
# Crear la figura y los ejes con tamaño específico
fig, ax = plt.subplots(figsize=(8, 4))

# Gráfico de dispersión con las alturas y pesos, el comando alpha es la transparencia del circulo
ax.scatter(alturas, pesos, alpha=0.7)

# Establecer el título del gráfico
ax.set_title('Altura vs. Peso de 50 alumnos')

# Etiqueta del eje x
ax.set_xlabel('Altura (cm.)')

# Etiqueta del eje y
ax.set_ylabel('Peso (kg.)')

# Mostrar el gráfico
plt.show()

# %%
# Crear la figura y los ejes
fig, ax = plt.subplots()

# Crear el gráfico de dispersión y asignar los valores de x, y el mapeo de colores
mapeo_colores = ax.scatter(df_lluvia['Aug'], df_lluvia['Sep'], c=df_lluvia.index, s=100)

# Agregar una barra de color al gráfico
fig.colorbar(mapeo_colores)

# Establecer el título del gráfico
ax.set_title('Precipitaciones Agosto-Septiembre')

# Etiqueta del eje x
ax.set_xlabel('Precipitaciones en Agosto (mm.)')

# Etiqueta del eje y
ax.set_ylabel('Precipitaciones en Septiembre (mm.)')

# Mostrar el gráfico
plt.show()

# %%
precipitaciones_acumuladas = df_lluvia.sum()
precipitaciones_acumuladas
# Out:
# Jan       11.186
# Feb       41.843
# Mar       63.733
# Apr      470.487
# May      952.272
# Jun    12809.663
# Jul    16340.395
# Aug    10529.357
# Sep     7642.245
# Oct     2783.320
# Nov      958.492
# Dec      230.646
# dtype: float64

# %%
# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(8, 4))

# Calcular la suma de precipitaciones acumuladas para cada mes
precipitaciones_acumuladas = df_lluvia.sum()

# Crear un gráfico de barras con los meses en el eje x y las precipitaciones acumuladas en el eje y
ax.bar(df_lluvia.columns, precipitaciones_acumuladas)

# Establecer el título del gráfico
ax.set_title('Precipitaciones acumuladas desde 1965 a 2002, según el mes')

# Etiqueta del eje y
ax.set_ylabel('Precipitación total (mm.)')

# Etiqueta del eje x
ax.set_xlabel('Mes')
# Out:
# Text(0.5, 0, 'Mes')

# %%
# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(8, 4))

# Calcular la suma de precipitaciones acumuladas para cada mes
precipitaciones_acumuladas = df_lluvia.sum()

# Lista de colores, un color por mes
colores = ['r', 'g', 'b', 'y', 'c', 'm', 'r', 'g', 'b', 'y', 'c', 'm']

# Crear un gráfico de barras con los meses en el eje x, las precipitaciones acumuladas en el eje y y colores distintos para cada barra
ax.bar(precipitaciones_acumuladas.index, precipitaciones_acumuladas, color=colores)

# Establecer el título del gráfico
ax.set_title('Precipitaciones acumuladas desde 1965 a 2002, según el mes')

# Etiqueta del eje y
ax.set_ylabel('Precipitación total (mm.)')

# Etiqueta del eje x
ax.set_xlabel('Mes')
# Out:
# Text(0.5, 0, 'Mes')

# %%
# La expresión df_lluvias.values.flatten() devuelve un array unidimensional que contiene 
# todos los valores de un DataFrame df_lluvias.
df_lluvia.values.flatten()
# Out:
# array([2.90000e-02, 6.90000e-02, 0.00000e+00, 2.16670e+01, 1.78590e+01,
#        1.02111e+02, 6.06071e+02, 4.02521e+02, 6.95110e+01, 5.24900e+00,
#        1.62320e+01, 2.20750e+01, 9.05000e-01, 0.00000e+00, 0.00000e+00,
#        2.98100e+00, 6.30080e+01, 9.40880e+01, 4.81942e+02, 5.93860e+01,
#        1.50624e+02, 1.30800e+00, 4.12140e+01, 4.13200e+00, 2.48000e-01,
#        3.39000e+00, 1.32000e+00, 1.34820e+01, 1.11160e+01, 2.51314e+02,
#        7.80006e+02, 1.81069e+02, 1.83757e+02, 5.04040e+01, 8.39300e+00,
#        3.76850e+01, 3.18000e-01, 3.03500e+00, 1.70400e+00, 2.33070e+01,
#        7.44100e+00, 1.79872e+02, 3.79354e+02, 1.71979e+02, 2.19884e+02,
#        7.39970e+01, 2.33260e+01, 2.02000e+00, 2.48000e-01, 2.52400e+00,
#        3.34000e-01, 4.56900e+00, 6.21300e+00, 3.93682e+02, 6.78354e+02,
#        3.97335e+02, 2.05413e+02, 2.40140e+01, 2.43850e+01, 1.95100e+00,
#        7.00000e-02, 0.00000e+00, 1.00000e-03, 1.62180e+01, 6.80360e+01,
# ...

# %%
len(df_lluvia.values.flatten())
# Out:
# 456

# %%
# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(8, 4))  

# Crear el histograma con los valores aplanados del DataFrame ccon el numero de intervalos
ax.hist(df_lluvia.values.flatten(), bins=10)

ax.set_xticks(range(0, 800, 50))  # Establecer las marcas en el eje x

 # Establecer el título del gráfico
ax.set_title('Histograma de precipitaciones') 
 # Etiqueta del eje x
ax.set_xlabel('Intervalos de precipitaciones (mm.)') 
 # Etiqueta del eje y
ax.set_ylabel('Frecuencia absoluta') 

plt.show()  # Mostrar el gráfico

# %%
# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(8, 4))

# Crear el boxplot con los datos transpuestos del DataFrame
ax.boxplot(x=df_lluvia.T)

# Establecer el título del gráfico
ax.set_title('Boxplot de precipitaciones')

# Etiqueta del eje x
ax.set_xlabel('Meses')

# Etiqueta del eje y
ax.set_ylabel('Precipitación (mm)')

# Mostrar el gráfico
plt.show()

# %%
# Lista de marcas de autos
cars = ['AUDI', 'BMW', 'FORD', 'TESLA', 'JAGUAR', 'MERCEDES']

# Datos de ventas de cada marca
data = [23, 17, 35, 29, 12, 41]

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(8, 7))
# Cambia el fondo del gráfico, por defecto es blanco, se puede usar directamente grey
fig.set_facecolor('#b2b2b2')   

# Crear el gráfico de pie
ax.pie(data, labels=cars, radius=0.7, startangle=90, explode=(0, 0, 0, 0, 0, 0.1), autopct="%1.1f%%", colors=sns.color_palette("hls", 7))

# Agregar una leyenda en la esquina inferior derecha
plt.legend(loc="lower right", labels=cars, fontsize=10)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# IMPORTANTE
# #b2b2b2: Es un valor hexadecimal que representa un color en el modelo de colores RGB (rojo, verde y azul). En este caso, representa un gris medio.
# labels: Es una lista con los nombres de las etiquetas que se mostrarán en el gráfico.
# radius: Es el radio del gráfico circular, determina el tamaño del gráfico.
# startangle: Es el ángulo inicial de la primera división del gráfico, determina la posición inicial de las divisiones.
# explode: Es una lista que especifica la separación de cada división del gráfico circular respecto al centro. Permite resaltar una porción del gráfico.
# autopct="%1.1f%%": Especifica el formato de etiqueta para mostrar el valor porcentual en cada porción del gráfico.
# colors: Es una variable que almacena una paleta de colores generada con la función color_palette() del paquete Seaborn en Python. Se utiliza para asignar colores a las porciones del gráfico.
# Estos elementos se combinan para crear un gráfico de pie con etiquetas, colores personalizados, tamaño y estilo visual.

# %%
# Crear la figura y los ejes con tamaño personalizado

fig, ax = plt.subplots(figsize=(14, 3)) 

# Graficar las precipitaciones de enero y febrero
ax.plot(df_lluvia.index, df_lluvia['Jan'], label='Precipitaciones de enero')
ax.plot(df_lluvia.index, df_lluvia['Feb'], label='Precipitaciones de febrero', color='C1')

# Obtener los valores máximos de enero y febrero
maximo_enero = df_lluvia['Jan'].max()
maximo_febrero = df_lluvia['Feb'].max()

# Graficar líneas horizontales para los máximos de enero y febrero
ax.axhline(maximo_enero, color='red', linestyle='--', alpha=0.5, linewidth=3, label='Máxima de enero')
ax.axhline(maximo_febrero, color='red', linestyle=':', alpha=0.5, linewidth=3, label='Máxima de febrero')

# Establecer etiquetas de los ejes y título del gráfico
ax.set_xlabel('Año')
ax.set_ylabel('Precipitación (mm.)')
ax.set_title('Precipitaciones de enero y febrero')

# Establecer los límites del eje x
ax.set_xlim(df_lluvia.index[0], df_lluvia.index[-1])

# Agregar leyenda al gráfico con tamaño de fuente personalizado
ax.legend(fontsize=8)

# Establecer el tamaño de las etiquetas de los ejes
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=6)

# Mostrar el gráfico
plt.show()

# %%
data=pd.read_csv('./HRDataset_v14.csv',sep=',',index_col=0)
data.head()
# Out:
#                           EmpID  MarriedID  MaritalStatusID  GenderID  \
# Employee_Name
# Adinolfi, Wilson  K       10026          0                0         1
# Ait Sidi, Karthikeyan     10084          1                1         1
# Akinkuolie, Sarah         10196          1                1         0
# Alagbe,Trina              10088          1                1         0
# Anderson, Carol           10069          0                2         0
#
#                           EmpStatusID  DeptID  PerfScoreID  \
# Employee_Name
# Adinolfi, Wilson  K                 1       5            4
# Ait Sidi, Karthikeyan               5       3            3
# Akinkuolie, Sarah                   5       5            3
# Alagbe,Trina                        1       5            3
# Anderson, Carol                     5       5            3
#
#                           FromDiversityJobFairID  Salary  Termd  ...  \
# Employee_Name                                                    ...
# ...

# %%
# Verificamos si hay nulos primero
data.isnull().sum()
# Out:
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ManagerID                       8
# ...

# %%
 # Establecer el estilo clásico de matplotlib
 # Orientado a objetos
mpl.style.use('classic') 

# Crear la figura y los ejes con tamaño personalizado
fig, ax = plt.subplots(figsize=(10, 6))  

# Crear el histograma
ax.hist(x=data.Salary, bins=None, density=False, orientation='vertical')

# Establecer etiquetas de los ejes y título del gráfico
ax.set_xlabel('Salario')
ax.set_ylabel('Frecuencia')
ax.set_title('Histograma de Salario')

# Mostrar el gráfico
plt.show()

# %%
 # Establecer el estilo clásico de matplotlib
 # Orientado a estados
mpl.style.use('classic') 
 # Crear una nueva figura con tamaño personalizado
 
plt.figure(figsize=(10, 6)) 
# Crear el histograma
plt.hist(x=data.Salary, bins=None, density=False, orientation='vertical')

# Establecer etiquetas de los ejes y título del gráfico
plt.xlabel('Salario')
plt.ylabel('Frecuencia')
plt.title('Histograma de Salario')

# Mostrar el gráfico
plt.show()

# %%
# Realizar una operación de agrupación y conteo en la columna "Department" del dataframe "data"
data_2 = data[['EmpID', 'Department']].groupby(by='Department').count()

data_2
# Out:
#                       EmpID
# Department
# Admin Offices             9
# Executive Office          1
# IT/IS                    50
# Production              209
# Sales                    31
# Software Engineering     11

# %%
# Obtener los índices de la columna "data_2"
data_2.index
# Out:
# Index(['Admin Offices', 'Executive Office', 'IT/IS', 'Production       ',
#        'Sales', 'Software Engineering'],
#       dtype='object', name='Department')

# %%
 #(basado en objetos)
 # Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(10, 6))

# Crear el gráfico de pastel con los datos de distribución de departamentos
ax.pie(data_2.EmpID, labels=data_2.index, autopct='%1.1f%%')

# Establecer el título del gráfico
ax.set_title('Piechart de distribucion de departamento')
# Out:
# Text(0.5, 1.0, 'Piechart de distribucion de departamento')

# %%
# Crear una nueva figura con el tamaño deseado ( basado en estados)
plt.figure(figsize=(10, 6))

# Crear el gráfico de pastel con los datos de distribución de departamentos
plt.pie(data_2.EmpID, labels=data_2.index, autopct='%1.1f%%')

# Establecer el título del gráfico
plt.title('Piechart de distribucion de departamento')
# Out:
# Text(0.5, 1.0, 'Piechart de distribucion de departamento')

# %%
# Calcula el recuento de valores únicos en la columna 'MaritalDesc' del dataframe 'data'
serie_estatus = data.MaritalDesc.value_counts()

# Imprime la serie 'serie_estatus' que contiene los recuentos de cada valor único en la columna 'MaritalDesc'
serie_estatus
# Out:
# Single       137
# Married      124
# Divorced      30
# Separated     12
# Widowed        8
# Name: MaritalDesc, dtype: int64

# %%
# Crea una figura y ejes para el gráfico
fig, ax = plt.subplots(figsize=(10,6))

# Crea un gráfico de barras utilizando los índices y los valores de la serie 'serie_estatus'
ax.bar(serie_estatus.index, serie_estatus)

# Establece el título del gráfico
ax.set_title('Frecuencia de estado civil')

# Establece la etiqueta del eje y
ax.set_ylabel('Frecuencia')

# Establece la etiqueta del eje x
ax.set_xlabel('Estado civil')
# Out:
# Text(0.5, 0, 'Estado civil')

# %%
import matplotlib.pyplot as plt

# Crea una nueva figura con el tamaño especificado
plt.figure(figsize=(10, 6))

# Crea un gráfico de barras utilizando los índices y los valores de la serie 'serie_estatus'
plt.bar(serie_estatus.index, serie_estatus)

# Establece el título del gráfico
plt.title('Frecuencia de estado civil')

# Establece la etiqueta del eje y
plt.ylabel('Frecuencia')

# Establece la etiqueta del eje x
plt.xlabel('Estado civil')
# Out:
# Text(0.5, 0, 'Estado civil')
